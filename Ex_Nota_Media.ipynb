# %%
#Lista de notas dos alunos
notas = [50,35,60,70,85, 92, 78, 90, 88]

# %%
#Calcula a média das notas
soma = 0
for nota in notas:
  soma += nota
media = soma / len(notas)

# %%
#Classifica os alunos com base na média
alunos_aprovados = []
alunos_reprovados = []
for nota in notas:
  if nota >= 70:
    alunos_aprovados.append(nota)
  else:
    alunos_reprovados.append(nota)

# %%
#Imprime os resultados
print("Notas dos alunos:", notas)
print("Média das notas:", media)
print("Alunos aprovados:", alunos_aprovados)
print("Alunos reprovados:", alunos_reprovados)
# Out:
# Notas dos alunos: [50, 35, 60, 70, 85, 92, 78, 90, 88]
# Média das notas: 72.0
# Alunos aprovados: [70, 85, 92, 78, 90, 88]
# Alunos reprovados: [50, 35, 60]
